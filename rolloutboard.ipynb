# %%
import numpy as np
import pandas as pd
import chess
from tensorflow.keras import models
from player import Player, Searcher, Single_Game

# %%
temp = Player('Models/full-puzzle.h5', searcher=Searcher)
temp.play_move()
# Out:
# Start times:  56201304.214832 57101304.214832
# 2 0.22852978 d2d3 20
# 3 0.10217059 d2d3 20
# 4 0.37543356 e2e3 20
# 5 0.25413233 e2e3 20
# 6 0.85010767 e2e4 20
# Move.from_uci('e2e4')

# %%
for _ in range(10):
    game = Single_Game(white= Player('Models/full-puzzle.h5', searcher=Searcher),
                       black= Player('Models/full-puzzle.h5', searcher=Searcher))
    print(game.play())
    game.game_board
# Out:
# Start times:  21811153.9619 21820153.9619
# 2 0.22852978 d2d3 20
# 3 0.10217059 d2d3 20
# 4 0.37543356 e2e3 20
# Start times:  21852930.922546998 21861930.922546998
# 2 0.24264443 b8c6 20
# 3 0.15923956 b8c6 20
# 4 0.17943746 g7g6 20
# Start times:  21889861.496372 21898861.496372
# 2 0.4270646 d1h5 30
# 3 0.5181896 d1h5 30
# 4 0.7702904 f1c4 30
# Start times:  21947144.339233 21956144.339233
# 2 0.21065536 f8g7 21
# 3 0.904659 g6g5 21
# 4 0.48349264 e7e5 21
# Start times:  21976171.317537 21985171.317537
# 2 0.85996866 c4f7 34
# 3 0.48349264 c4f7 34
# 4 0.990731 d1h5 34
# Start times:  22057907.076452002 22066907.076452002
# 2 0.48199686 d8f6 31
# 3 0.9043133 g6h5 31
# 4 0.7632235 f8e7 31
# Start times:  22130970.16195 22139970.16195
# 2 0.9574788 c4f7 43
# 3 0.7438523 g1f3 43
# 4 0.96467614 h5e5 43
# Start times:  22244474.040183 22253474.040183
# 2 0.46134531 b8c6 18
# 3 0.96467614 g8h6 18
# 4 0.3664122 d7d6 18
# Start times:  22293665.319829002 22302665.319829002
# ...
