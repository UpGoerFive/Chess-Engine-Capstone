# %%
import numpy as np
import pandas as pd
import chess
from tensorflow.keras import models
from player import Player, Searcher, Single_Game

# %%
for _ in range(10):
    game = Single_Game(white= Player('Models/full-puzzle.h5', searcher=Searcher),
                       black= Player('Models/full-puzzle.h5', searcher=Searcher))
    print(game.play())
    game.game_board
# Out:
# Start times:  11665076.156829 11674076.156829
# 2 0.22852978 d2d3
# 3 0.10217059 d2d3
# 4 0.37543356 e2e3
# Start times:  11706051.192509 11715051.192509
# 2 0.24264443 b8c6
# 3 0.15923956 b8c6
# 4 0.17943746 g7g6
# Start times:  11743227.885839 11752227.885839
# 2 0.4270646 d1h5
# 3 0.5181896 d1h5
# 4 0.7702904 f1c4
# Start times:  11800089.284301 11809089.284301
# 2 0.21065536 f8g7
# 3 0.904659 g6g5
# 4 0.48349264 e7e5
# Start times:  11826354.325209001 11835354.325209001
# 2 0.85996866 c4f7
# 3 0.48349264 c4f7
# 4 0.990731 d1h5
# Start times:  11901416.330542998 11910416.330542998
# 2 0.48199686 d8f6
# 3 0.9043133 g6h5
# 4 0.7632235 f8e7
# Start times:  11969485.055316 11978485.055316
# 2 0.9574788 c4f7
# 3 0.7438523 g1f3
# 4 0.96467614 h5e5
# Start times:  12075071.406378 12084071.406378
# 2 0.46134531 b8c6
# 3 0.96467614 g8h6
# 4 0.3664122 d7d6
# Start times:  12120239.502636 12129239.502636
# 2 0.8741476 c4f7
# 3 0.62553924 e5h5
# 4 0.9711975 h2h4
# ...

# %%
move_list = ['e2e3', 'g7g6', 'f1c4', 'e7e5', 'd1h5', 'f8e7', 'h5e5', 'd7d6', 'h2h4', 'c8g4', 'c4f1', 'b8c6', 'e3e4', 'c6d4', 'e5d4', 'e7h4', 'g1h3', 'd8e7', 'h3g1', 'h4g3', 'h1h2', 'g8f6', 'd4d6', 'g3f2', 'e1f2', 'c7d6', 'e4e5', 'h7h5', 'e5d6', 'e7f8', 'h2h1', 'g4f5', 'b1a3', 'f6g4', 'f2e1', 'f8d6', 'g1h3', 'd6e5', 'e1d1', 'e5d4', 'c2c3', 'd4a4', 'b2b3', 'f5c2', 'd1e1', 'c2f5', 'a3b5', 'e8c8', 'b3a4', 'd8d4', 'c3c4', 'h8d8', 'f1d3', 'g4e3', 'h3g1', 'd4e4', 'd3f1', 'd8e8', 'b5d6', 'c8b8', 'a1b1', 'a7a6', 'c1a3', 'f5g4', 'd6f7', 'e8h8', 'a3b2', 'b8c8', 'f7d6', 'c8b8', 'b2e5', 'b8a7', 'd6b5', 'a7a8', 'b5c7', 'a8a7', 'c7a6', 'h8b8', 'e5d6', 'b8f8', 'g1h3', 'e3c2']

# %%
game = chess.Board()
move_list = ['e2e3', 'g7g6', 'f1c4', 'e7e5', 'd1h5', 'f8e7', 'h5e5', 'd7d6', 'h2h4', 'c8g4', 'c4f1', 'b8c6', 'e3e4', 'c6d4', 'e5d4', 'e7h4', 'g1h3', 'd8e7', 'h3g1', 'h4g3', 'h1h2', 'g8f6', 'd4d6', 'g3f2', 'e1f2', 'c7d6', 'e4e5', 'h7h5', 'e5d6', 'e7f8', 'h2h1', 'g4f5', 'b1a3', 'f6g4', 'f2e1', 'f8d6', 'g1h3', 'd6e5', 'e1d1', 'e5d4', 'c2c3', 'd4a4', 'b2b3', 'f5c2', 'd1e1', 'c2f5', 'a3b5', 'e8c8', 'b3a4', 'd8d4', 'c3c4', 'h8d8', 'f1d3', 'g4e3', 'h3g1', 'd4e4', 'd3f1', 'd8e8', 'b5d6', 'c8b8', 'a1b1', 'a7a6', 'c1a3', 'f5g4', 'd6f7', 'e8h8', 'a3b2', 'b8c8', 'f7d6', 'c8b8', 'b2e5', 'b8a7', 'd6b5', 'a7a8', 'b5c7', 'a8a7', 'c7a6', 'h8b8', 'e5d6', 'b8f8', 'g1h3', 'e3c2']

for move in move_list:
    game.push_uci(move)
    chess.svg.board(game)
